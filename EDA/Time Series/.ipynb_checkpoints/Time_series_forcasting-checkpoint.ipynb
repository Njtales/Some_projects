# %% [markdown]
# # Time_Series_Forecasting
#
# ARIMA stands for Autoregressive Integrated Moving Average. It is an algorithm used for forecasting Time Series Data.

# %%
import pandas as pd
import yfinance as yf
import datetime
from datetime import date, timedelta
today = date.today()

d1 = today.strftime("%Y-%m-%d")
end_date = d1
d2 = date.today() - timedelta(days=365)
d2 = d2.strftime("%Y-%m-%d")
start_date = d2

data = yf.download('GOOG', 
                      start=start_date, 
                      end=end_date, 
                      progress=False)

data["Date"] = data.index
data = data[["Date", "Open", "High", "Low", "Close", "Adj Close", "Volume"]]
data.reset_index(drop=True, inplace=True)
data.tail()
# Out:
#           Date        Open        High         Low       Close   Adj Close  \
# 248 2022-08-11  122.080002  122.339996  119.550003  119.820000  119.820000
# 249 2022-08-12  121.160004  122.650002  120.400002  122.650002  122.650002
# 250 2022-08-15  122.209999  123.260002  121.570000  122.879997  122.879997
# 251 2022-08-16  122.320000  123.227997  121.535004  122.510002  122.510002
# 252 2022-08-17  120.930000  122.150002  120.199997  120.320000  120.320000
#
#        Volume
# 248  16671600
# 249  16106600
# 250  15525000
# 251  15626200
# 252  17589200

# %%
data = data[["Date", "Close"]]
print(data.head())
# Out:
#         Date       Close
# 0 2021-08-17  137.300507
# 1 2021-08-18  136.570007
# 2 2021-08-19  136.913498
# 3 2021-08-20  138.436996
# 4 2021-08-23  141.099503

# %%
import matplotlib.pyplot as plt
plt.style.use('fivethirtyeight')
plt.figure(figsize=(15, 10))
plt.plot(data["Date"], data["Close"])

# %%
from statsmodels.graphics.tsaplots import plot_pacf
plot_pacf(data["Close"], lags = 100)
# Out:
# D:\Users\NYK-PC\AppData\Local\Programs\Python\Python310\lib\site-packages\statsmodels\graphics\tsaplots.py:348: FutureWarning: The default method 'yw' can produce PACF values outside of the [-1,1] interval. After 0.13, the default will change tounadjusted Yule-Walker ('ywm'). You can use this method now by setting method='ywm'.
#   warnings.warn(

# %%
pd.plotting.autocorrelation_plot(data["Close"])
# Out:
# <AxesSubplot:xlabel='Lag', ylabel='Autocorrelation'>

# %%
import statsmodels.api as sm
import warnings
model=sm.tsa.statespace.SARIMAX(data['Close'],
                                order=(p, d, q),
                                seasonal_order=(p, d, q, 12))
model=model.fit()
print(model.summary())
# Out:
# D:\Users\NYK-PC\AppData\Local\Programs\Python\Python310\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# D:\Users\NYK-PC\AppData\Local\Programs\Python\Python310\lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# D:\Users\NYK-PC\AppData\Local\Programs\Python\Python310\lib\site-packages\statsmodels\base\model.py:604: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
#                                      SARIMAX Results
# ==========================================================================================
# Dep. Variable:                              Close   No. Observations:                  253
# Model:             SARIMAX(5, 1, 2)x(5, 1, 2, 12)   Log Likelihood                -586.484
# Date:                            Thu, 18 Aug 2022   AIC                           1202.968
# Time:                                    20:48:14   BIC                           1255.178
# Sample:                                         0   HQIC                          1224.005
#                                             - 253
# Covariance Type:                              opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.1041      0.677      0.154      0.878      -1.222       1.430
# ar.L2          0.7705      0.601      1.282      0.200      -0.408       1.949
# ar.L3         -0.0597      0.099     -0.606      0.545      -0.253       0.134
# ar.L4         -0.0460      0.088     -0.523      0.601      -0.219       0.127
# ar.L5          0.0794      0.079      1.011      0.312      -0.074       0.233
# ma.L1         -0.1727      0.674     -0.256      0.798      -1.494       1.148
# ma.L2         -0.7549      0.647     -1.167      0.243      -2.023       0.513
# ar.S.L12      -0.6685      0.464     -1.441      0.150      -1.578       0.241
# ar.S.L24       0.1460      0.158      0.921      0.357      -0.165       0.457
# ar.S.L36       0.1468      0.166      0.886      0.376      -0.178       0.472
# ar.S.L48      -0.0947      0.128     -0.738      0.461      -0.346       0.157
# ar.S.L60      -0.1624      0.089     -1.830      0.067      -0.336       0.012
# ma.S.L12      -0.3036      0.508     -0.597      0.550      -1.299       0.692
# ma.S.L24      -0.6478      0.595     -1.090      0.276      -1.813       0.517
# sigma2         6.7792      1.948      3.480      0.001       2.961      10.598
# ===================================================================================
# Ljung-Box (L1) (Q):                   0.00   Jarque-Bera (JB):                 4.63
# Prob(Q):                              0.97   Prob(JB):                         0.10
# Heteroskedasticity (H):               2.01   Skew:                             0.13
# Prob(H) (two-sided):                  0.00   Kurtosis:                         3.63
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
predictions = model.predict(len(data), len(data)+10)
print(predictions)
# Out:
# 253    118.995793
# 254    119.036129
# 255    119.589679
# 256    119.568611
# 257    119.023663
# 258    118.520517
# 259    118.701942
# 260    117.342304
# 261    119.495675
# 262    118.391896
# 263    116.795596
# Name: predicted_mean, dtype: float64

# %%
data["Close"].plot(legend=True, label="Training Data", figsize=(15, 10))
predictions.plot(legend=True, label="Predictions")
# Out:
# <AxesSubplot:>
